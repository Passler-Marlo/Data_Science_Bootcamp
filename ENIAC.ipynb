# %% [markdown]
# <a href="https://colab.research.google.com/github/Passler-Marlo/Data_Science_Bootcamp/blob/main/ENIAC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task Board

# %% [markdown]
# *   Datacleaning
#   * Brands
#   * Orderlines
#   * Orders
#   * Products
#
# *  WHAT NEXT?

# %%
import pandas as pd

# %% [markdown]
# ## Schema
# Here we work out the schema...

# %% [markdown]
# ### Brands --> sku(short) --> Orderlines

# %%
df_brands['short']

#is connected to

df_orderlines['sku'].str[:3]

## We can add  the short column to the orderlines table for merging

#. df_orderlines['short'] = df_orderlines['sku'].str[:3]
# Out:
# 0         OTT
# 1         LGE
# 2         PAR
# 3         WDT
# 4         JBL
#          ...
# 293978    JBL
# 293979    PAC
# 293980    APP
# 293981    BEZ
# 293982    APP
# Name: sku, Length: 293983, dtype: object

# %% [markdown]
# ### Orderlines --> id_order_id --> Orders

# %% [markdown]
# Orderlines[id_order] machtes Orders[order_id]

# %% [markdown]
# Insights
#
# * There are way more ids in orderlines than in orders despite that
# *

# %%
df_orderlines.sort_values('id_order')
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 1021    1121139    241319           0                 1  JBL0123      44.99
# 14611   1153623    241355           0                 2  WAC0171      67.99
# 142509  1398738    241423           0                 1  LAC0212     129.16
# 219383  1529178    242832           0                 1  PAR0074      10.77
# 28729   1181923    243330           0                 1  OWC0074      77.99
# ...         ...       ...         ...               ...      ...        ...
# 293977  1650198    527397           0                 1  JBL0122      42.99
# 293978  1650199    527398           0                 1  JBL0122      42.99
# 293979  1650200    527399           0                 1  PAC0653     141.58
# 293980  1650201    527400           0                 2  APP0698       9.99
# 293982  1650203    527401           0                 1  APP0927      13.99
#
#                        date
# ...

# %%
df_orders
# Out:
#         order_id         created_date  total_paid            state
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled
# 1         241423  2017-11-06 13:10:02      136.15        Completed
# 2         242832  2017-12-31 17:40:03       15.76        Completed
# 3         243330  2017-02-16 10:59:38       84.98        Completed
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                  ...         ...              ...
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order
#
# [226909 rows x 4 columns]

# %%
# Merge df_orders and df_orderlines using an outer join
df_orders.merge(df_orderlines, left_on='order_id', right_on='id_order', how='left')
# Out:
#         order_id         created_date  total_paid            state         id  \
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled  1121139.0
# 1         241423  2017-11-06 13:10:02      136.15        Completed  1398738.0
# 2         242832  2017-12-31 17:40:03       15.76        Completed  1529178.0
# 3         243330  2017-02-16 10:59:38       84.98        Completed  1181923.0
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled  1437153.0
# ...          ...                  ...         ...              ...        ...
# 315957    527397  2018-03-14 13:56:38       42.99      Place Order  1650198.0
# 315958    527398  2018-03-14 13:57:25       42.99  Shopping Basket  1650199.0
# 315959    527399  2018-03-14 13:57:34      141.58  Shopping Basket  1650200.0
# 315960    527400  2018-03-14 13:57:41       19.98  Shopping Basket  1650201.0
# 315961    527401  2018-03-14 13:58:36       18.98      Place Order  1650203.0
#
# ...

# %% [markdown]
# ### Orderlines --> sku --> Products

# %% [markdown]
# Match on sku

# %%
df_orderlines
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 0       1119109    299539           0                 1  OTT0133      18.99
# 1       1119110    299540           0                 1  LGE0043     399.00
# 2       1119111    299541           0                 1  PAR0071     474.05
# 3       1119112    299542           0                 1  WDT0315      68.39
# 4       1119113    299543           0                 1  JBL0104      23.74
# ...         ...       ...         ...               ...      ...        ...
# 293978  1650199    527398           0                 1  JBL0122      42.99
# 293979  1650200    527399           0                 1  PAC0653     141.58
# 293980  1650201    527400           0                 2  APP0698       9.99
# 293981  1650202    527388           0                 1  BEZ0204      19.99
# 293982  1650203    527401           0                 1  APP0927      13.99
#
#                        date
# ...

# %%
df_products
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %% [markdown]
# ### Products --> sku(short) --> Brands

# %% [markdown]
# Yep

# %% [markdown]
# ## The Brands database
# Here we analyse df_brands...

# %%
download_link = "https://drive.google.com/uc?export=download&id=1m1ThDDIYRTTii-rqM5SEQjJ8McidJskD"

df_brands = pd.read_csv(download_link)

# %%
df_brands
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %% [markdown]
# ##

# %%
info_brands = df_brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   short   187 non-null    object
#  1   long    187 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %% [markdown]
# ## The Oderlines Database
# Here we anaylse the df_oderlines...

# %%
download_link2 = "https://drive.google.com/uc?export=download&id=1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG"

df_orderlines = pd.read_csv(download_link2)

# %%
df_orderlines
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 0       1119109    299539           0                 1  OTT0133      18.99
# 1       1119110    299540           0                 1  LGE0043     399.00
# 2       1119111    299541           0                 1  PAR0071     474.05
# 3       1119112    299542           0                 1  WDT0315      68.39
# 4       1119113    299543           0                 1  JBL0104      23.74
# ...         ...       ...         ...               ...      ...        ...
# 293978  1650199    527398           0                 1  JBL0122      42.99
# 293979  1650200    527399           0                 1  PAC0653     141.58
# 293980  1650201    527400           0                 2  APP0698       9.99
# 293981  1650202    527388           0                 1  BEZ0204      19.99
# 293982  1650203    527401           0                 1  APP0927      13.99
#
#                        date
# ...

# %%
info_oderlines = df_oderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %% [markdown]
# ## The Orders Database
# Here we anaylse the df_orders...

# %%
download_link3 = "https://drive.google.com/uc?export=download&id=1Vu0q91qZw6lqhIqbjoXYvYAQTmVHh6uZ"

df_orders = pd.read_csv(download_link3)

# %%
df_orders
# Out:
#         order_id         created_date  total_paid            state
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled
# 1         241423  2017-11-06 13:10:02      136.15        Completed
# 2         242832  2017-12-31 17:40:03       15.76        Completed
# 3         243330  2017-02-16 10:59:38       84.98        Completed
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                  ...         ...              ...
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order
#
# [226909 rows x 4 columns]

# %% [markdown]
# ## The Products Database
# Here we anaylse the df_products...

# %%
download_link4 = "https://drive.google.com/uc?export=download&id=1afxwDXfl-7cQ_qLwyDitfcCx3u7WMvkU"

df_products = pd.read_csv(download_link4)

# %%
df_products
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...
